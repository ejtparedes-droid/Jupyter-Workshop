# %% [markdown]
# # 🐍 Hoja de Trabajo: Conceptos Básicos de Python
# ## Libreta de Jupyter - Evaluación de Expresiones
#
# **Nombre del estudiante:** Jose Tomas Paredes
# **Fecha:** 05/11/2025
# **Curso:** IB Computer Science SL
#
# ---

# %% [markdown]
# ## 📋 Instrucciones Generales
# Esta libreta de trabajo te guiará paso a paso para explicar y practicar los conceptos básicos de Python que hemos estudiado en CodeHS (capítulos 1-5, excluyendo Karel).
#
# **Objetivos de aprendizaje:**
# - Explicar conceptos fundamentales
# - Predecir valor y tipo de dato ANTES de ejecutar
# - Crear ejemplos propios con comentarios explicativos

# %% [markdown]
# ## 📝 PARTE 1: VARIABLES Y TIPOS DE DATOS
#
# ### 1.1 ¿Qué es una variable?
# En la celda Markdown debajo, explica qué es una variable en Python.

# %% [markdown]
# Tu explicación: Una variable es el nombre para definir un valor.

# %% [markdown]
# ### 1.2. Enteros (int)
# Explica qué es y da un ejemplo abajo.

# %% [markdown]
# Un entero es una variable numerica sin decimales.

# %%
# Ejemplo
edad = 16
numero_de_partidos = 5

# %% [markdown]
# - Valor de la variable: 16
# - Tipo de dato: Entero

# %%
print(type(numero_de_partidos))
# Out:
# <class 'int'>

# %% [markdown]
# ### 1.2. Números decimales (float)
# Explica qué es y da un ejemplo abajo.

# %% [markdown]
# Un número es...

# %%
# Ejemplo
precio = 4.50

# %% [markdown]
# - Valor de la variable: 4.50
# - Tipo de dato: float

# %%
print(type(precio))
# Out:
# <class 'float'>

# %% [markdown]
# ### 1.2. Cadenas de texto (string)
# Explica qué es y da un ejemplo abajo.

# %% [markdown]
# Un cadenas es...

# %%
# Ejemplo
nombre = 'Pablo'

# %% [markdown]
# - Valor de la variable: Pablo
# - Tipo de dato: string

# %%
print(type(nombre))
# Out:
# <class 'str'>

# %% [markdown]
# ### 1.2. Booleanos (bool)
# Explica qué es y da un ejemplo abajo.

# %% [markdown]
# Un booleanos es...

# %%
# Ejemplo
es_mayor = True

# %% [markdown]
# - Valor de la variable: True
# - Tipo de dato: bool

# %%
print(type(es_mayor))
# Out:
# <class 'bool'>

# %% [markdown]
# ## 🖨️ PARTE 2: FUNCIÓN PRINT()
# ### ¿Qué hace print()?
# Explica qué hace print() en Markdown abajo, y realiza tres ejemplos:

# %% [markdown]
# La función print() sirve para...

# %% [markdown]
# #### Ejemplo: Imprimir un texto literal

# %%
print('Hola mundo')
# Out:
# Hola mundo

# %% [markdown]
# ¿Qué se imprimirá en pantalla?: Hola mundo

# %% [markdown]
# #### Ejemplo: Imprimir una variable

# %%
mensaje = 'Hola'
print(mensaje)
# Out:
# Hola

# %% [markdown]
# ¿Qué se imprimirá en pantalla?: Hola

# %% [markdown]
# #### Ejemplo: Imprimir múltiple elementos

# %%
a = 5
b = 3
print('Suma:', a + b)
# Out:
# Suma: 8

# %% [markdown]
# ¿Qué se imprimirá en pantalla?: Suma: 8

# %% [markdown]
# ## ➕ PARTE 3: OPERADORES ARITMÉTICOS
# Completa la tabla de operadores:

# %% [markdown]
# | Operador | Significado | Ejemplo | Resultado |
# |---|---|---|---|
# | + |suma               | 5 + 3 |8     |
# | - |resta             | 10 - 6 |    4    |
# | * |multiplicacion             | 4 * 3 |    12    |
# | / |division             | 7 / 2 |     3.5   |
# | // |division entera             | 8 // 2 |   4     |
# | % |operador modulo               | 9 % 2 |    1    |
# | ** |potencia       | 2 ** 4 |    16    |

# %% [markdown]
# #### Operador +
# Predecir el resultado de la expresión:

# %%
resultado = 5 + 3

# %% [markdown]
# - Valor de resultado: 8
# - Tipo de dato: integer
# - Razonamiento: + es un operador matematico que suma dos o mas numeros.

# %%
print(resultado)
print(type(resultado))
# Out:
# 8
# <class 'int'>

# %% [markdown]
# #### Operador -
# Predecir el resultado de la expresión:

# %%
resultado = 10 - 6

# %% [markdown]
# - Valor de resultado: 4
# - Tipo de dato: integer
# - Razonamiento: - es un operador matematico que resta dos o mas numeros.

# %%
print(resultado)
print(type(resultado))
# Out:
# 4
# <class 'int'>

# %% [markdown]
# #### Operador *
# Predecir el resultado de la expresión:

# %%
resultado = 4 * 3

# %% [markdown]
# - Valor de resultado: 12
# - Tipo de dato: integer
# - Razonamiento: * es un operador matematico que multiplica dos o mas numeros.

# %%
print(resultado)
print(type(resultado))
# Out:
# 12
# <class 'int'>

# %% [markdown]
# #### Operador /
# Predecir el resultado de la expresión:

# %%
resultado = 7 / 2

# %% [markdown]
# - Valor de resultado: 3.5
# - Tipo de dato: float
# - Razonamiento: / es un operador matematico que divide dos numeros.

# %%
print(resultado)
print(type(resultado))
# Out:
# 3.5
# <class 'float'>

# %% [markdown]
# #### Operador //
# Predecir el resultado de la expresión:

# %%
resultado = 8 // 2

# %% [markdown]
# - Valor de resultado: 4
# - Tipo de dato: integer
# - Razonamiento: // es un operador matematico que divide dos numeros y los redondea al numero mas cercano.

# %%
print(resultado)
print(type(resultado))
# Out:
# 4
# <class 'int'>

# %% [markdown]
# #### Operador %
# Predecir el resultado de la expresión:

# %%
resultado = 9 % 2

# %% [markdown]
# - Valor de resultado:
# - Tipo de dato: integer
# - Razonamiento: % es un operador matematico que funciona dividiendo el primer número por el segundo y devolviendo el resto de esa división entera.

# %%
print(resultado)
print(type(resultado))
# Out:
# 1
# <class 'int'>

# %% [markdown]
# #### Operador **
# Predecir el resultado de la expresión:

# %%
resultado = 2 ** 4

# %% [markdown]
# - Valor de resultado: 16
# - Tipo de dato: integer
# - Razonamiento: ** es un operador matematico que multiplica dos numeros, uno por el otro. Osea 2 ** 4 es 2 * 2, 4 veces

# %%
print(resultado)
print(type(resultado))
# Out:
# 16
# <class 'int'>

# %% [markdown]
# ## 🔤 PARTE 4: OPERADORES DE CADENAS (STRINGS)
# ### Concatenación

# %%
nombre = 'Luis'
apellido = 'Tello'
nombre_completo = nombre + ' ' + apellido

# %% [markdown]
# - Valor de nombre_completo: Luis Tello
# - Tipo de dato: string

# %%
print(nombre_completo)
print(type(nombre_completo))
# Out:
# Luis Tello
# <class 'str'>

# %% [markdown]
# ## 📥 PARTE 5: INPUT DEL USUARIO
# Pregunta por el nombre y edad, predice los resultados antes de ejecutar.

# %%
nombre = input('¿Cuál es tu nombre?')
print('Hola, ' + nombre)
# Out:
# Hola, Jose Paredes

# %%
edad = int(input('¿Cuántos años tienes?'))
print('En un año tendrás:', edad + 1)
# Out:
# En un año tendrás: 17

# %% [markdown]
# ## 🔍 PARTE 6: OPERADORES DE COMPARACIÓN
# ### Predice el resultado antes de ejecutar.

# %%
a = 10
b = 5
resultado = a > b
print(resultado)
print(type(resultado))
# Out:
# True
# <class 'bool'>

# %%
a = 10
b = 10
resultado = a == b
print(resultado)
print(type(resultado))
# Out:
# True
# <class 'bool'>

# %% [markdown]
# ## 🧮 PARTE 7: OPERADORES LÓGICOS
# Completa las tablas de verdad y prueba los siguientes ejemplos:

# %%
edad = 20
tiene_licencia = True
puede_conducir = edad >= 18 and tiene_licencia
print(puede_conducir)
# Out:
# True

# %%
es_fin_de_semana = False
es_feriado = True
puede_descansar = es_fin_de_semana or es_feriado
print(puede_descansar)
# Out:
# True

# %%
esta_lloviendo = False
debe_llevar_paraguas = esta_lloviendo
print(debe_llevar_paraguas)
# Out:
# False

# %% [markdown]
# ## ⚡ PARTE 8: CONDICIONALES (IF, ELIF, ELSE)
# Prueba los siguientes ejemplos y predice el resultado:

# %%
edad = 17
if edad >= 18:
    print('Eres mayor de edad')

# %%
edad = 19
if edad >= 18:
    print('Eres mayor de edad')
# Out:
# Eres mayor de edad

# %%
edad = 15
if edad >= 18:
    print('Mayor')
else:
    print('Menor')
# Out:
# Menor

# %%
calificacion = 85
if calificacion >= 90:
    print('Excelente (A)')
elif calificacion >= 80:
    print('Muy bien (B)')
elif calificacion >= 70:
    print('Bien (C)')
else:
    print('Necesitas mejorar')
# Out:
# Muy bien (B)

# %% [markdown]
# ## 🎯 PARTE 9: AUTOEVALUACIÓN
# Crea 5 expresiones propias, predice, verifica y reflexiona.

# %%
# Expresión 1
# Escribe tu código aquí
a = 16
b = 24
print("a = 16")
print("b = 24")
print("a + b =", a + b)
# Out:
# a = 16
# b = 24
# a + b = 40

# %% [markdown]
# - Predicción: 40
# - Explicación: Escribi un codigo primero definiendo variables y sus valores, despues escribi un codigo corto explicando el valor de cada variable y la suma de los dos.

# %%
# Verifica tu predicción

# %% [markdown]
# - ¿Tu predicción fue correcta? Si
# - Si hubo diferencias, ¿por qué? No hubo diferencias

# %%
# Expresión 2
# Escribe tu código aquí
a = 16
b = 24
print("a = 16")
print("b = 24")
print("a * b =", a * b)

# %% [markdown]
# - Predicción: 384
# - Explicación: Es la misma funcion, en cambio ahora multiplica en vez de sumar los numeros.

# %%
# Verifica tu predicción

# %% [markdown]
# - ¿Tu predicción fue correcta? Si
# - Si hubo diferencias, ¿por qué? No hubo diferencias

# %%
# Expresión 3
# Escribe tu código aquí

print("Are you a legal Adult?")

age = 16

if age >= 18:
    print("You are a Legal adult")
else:
    print("You are still a teenager")
# Out:
# Are you a legal Adult?
# You are still a teenager

# %% [markdown]
# - Predicción: "You are still a teenager"
# - Explicación: Este codigo chequea si la edad es sobre 18, y si no lo es escribe el mensaje "You are still a teenager"

# %%
# Verifica tu predicción

# %% [markdown]
# - ¿Tu predicción fue correcta? Si
# - Si hubo diferencias, ¿por qué? No hubo diferencias

# %%
# Expresión 4
# Escribe tu código aquí

age = 20
has_license= True
if age >= 18:
    if has_license:
        "can_drive"

if "can_drive":
    print("You can legally drive")
# Out:
# You can legally drive

# %% [markdown]
# - Predicción: "You can legally drive"
# - Explicación: El codigo busca si la edad es mayor a 18, y si es que tiene licensia, lo que despues confirma que el usuario puede manejar legalemente si es que entra en los requicitos

# %%
# Verifica tu predicción

# %% [markdown]
# - ¿Tu predicción fue correcta? Si
# - Si hubo diferencias, ¿por qué? No hubo diferencias

# %%
# Expresión 5
# Escribe tu código aquí

name = input("What is your name?:")
print("Hello, "+ nombre)

age = int(input("How old are you?"))
print("In one year you'll be", age + 1)
# Out:
# Hello, Jose Paredes
# In one year you'll be 17

# %% [markdown]
# - Predicción: "Hello, Jose Paredes
#                In one year you'll be 17"
# - Explicación: El codigo le pide el nombre y edad al usuario

# %%
# Verifica tu predicción

# %% [markdown]
# - ¿Tu predicción fue correcta? Si
# - Si hubo diferencias, ¿por qué? No hubo diferencias

# %% [markdown]
# ## 🏆 PARTE 10: DESAFÍO FINAL
# Crea un programa que solicita nombre, edad y calificación, y da mensajes personalizados.

# %%
# Programa integrador
nombre = input('Nombre: ')
edad = int(input('Edad: '))
calificacion = int(input('Calificación: '))
if edad >= 18:
    print('Eres mayor de edad')
else:
    print('Eres menor de edad')
if calificacion >= 60:
    print('¡Aprobaste!')
else:
    print('Sigue intentando...')
print('Gracias por participar,', nombre)
# Out:
# Eres menor de edad
# ¡Aprobaste!
# Gracias por participar, Jose Paredes

# %% [markdown]
# ## 📊 CRITERIOS DE EVALUACIÓN
# ### Rúbrica de autoevaluación
# | Criterio | Nivel 1 | Nivel 2 | Nivel 3 | Nivel 4 | Mi nivel |
# |----------|---------|---------|---------|---------|----------|
# | Explicaciones | Incompletas | Básicas | Claras y correctas | Claras y ejemplos propios | 4 |
# | Predicciones | <50% correctas | 50-70% | 70-85% | >85% | 4 |
# | Razonamiento | No explica | Parcial | Paso a paso | Detallado y justifica | 4 |
# | Markdown/código | Incorrecto | Básico | Correcto | Avanzado | 4 |
# | Reflexión | No reflexiona | Identifica | Explica errores | Explica y propone mejoras | 4 |

# %% [markdown]
# ## ✅ LISTA DE VERIFICACIÓN FINAL
# - [x] Todas las explicaciones
# - [x] Ejemplos de código
# - [x] Predicciones antes de ejecutar
# - [x] Verificaciones
# - [x] Autoevaluación
# - [x] Desafío final
# - [x] Reflexiones
# - [x] Rúbrica completada

# %% [markdown]
# ## 🎓 REFLEXIÓN FINAL
# ### 1. ¿Qué concepto fue difícil? ¿Por qué?
# El modulo es complicado de entender, porque no tiene mucho sentido en la manera que funciona hasta que haces la matematica tu.
# ### 2. ¿Cómo te ayudó predecir antes de ejecutar?
# No en mucho, en mi opinion es mejor probar tu codigo para verificar que funcione en vez de predecir.
# ### 3. ¿Qué estrategias usaste mentalmente?
# Mucha matematica.
# ### 4. ¿Dónde usarías estos conceptos en la vida real?
# En la ingenieria de programas.
# ### 5. ¿Qué quieres aprender después?
# Codigos y funciones mas complicadas para escribir codigos mas complejos.
